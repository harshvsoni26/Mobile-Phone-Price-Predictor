# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot

# %%
mobile = pd.read_csv("smartphones - smartphones.csv")

# %%
mobile.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %%
mobile.shape
# Out:
# (1020, 11)

# %%
mobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
mobile.isnull().sum()
# Out:
# model          0
# price          0
# rating       141
# sim            0
# processor      0
# ram            0
# battery        0
# display        0
# camera         1
# card           7
# os            17
# dtype: int64

# %%
mobile.isnull().mean()
# Out:
# model        0.000000
# price        0.000000
# rating       0.138235
# sim          0.000000
# processor    0.000000
# ram          0.000000
# battery      0.000000
# display      0.000000
# camera       0.000980
# card         0.006863
# os           0.016667
# dtype: float64

# %%
mobile = mobile.dropna(subset=['camera'])

# %%
mobile = mobile.dropna(subset=['card'])

# %%
mobile = mobile.dropna(subset=['os'])

# %%
mobile.isnull().sum()
# Out:
# model          0
# price          0
# rating       124
# sim            0
# processor      0
# ram            0
# battery        0
# display        0
# camera         0
# card           0
# os             0
# dtype: int64

# %%
mobile.shape
# Out:
# (1003, 11)

# %%
mobile['rating']
# Out:
# 0       89.0
# 1       81.0
# 2       75.0
# 3       81.0
# 4       82.0
#         ...
# 1015    83.0
# 1016    75.0
# 1017    85.0
# 1018    80.0
# 1019    74.0
# Name: rating, Length: 1003, dtype: float64

# %%
mobile['rating'].mean()
# Out:
# 78.25824800910125

# %%
mobile.fillna(78.0,inplace = True)

# %%
mobile['rating']
# Out:
# 0       89.0
# 1       81.0
# 2       75.0
# 3       81.0
# 4       82.0
#         ...
# 1015    83.0
# 1016    75.0
# 1017    85.0
# 1018    80.0
# 1019    74.0
# Name: rating, Length: 1003, dtype: float64

# %%
mobile.isnull().sum()
# Out:
# model        0
# price        0
# rating       0
# sim          0
# processor    0
# ram          0
# battery      0
# display      0
# camera       0
# card         0
# os           0
# dtype: int64

# %%
mobile.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %%
mobile['brand'] = mobile['model'].apply(lambda x: x.split()[0])

# %%
mobile.head(10)
# Out:
#                                      model    price  rating  \
# 0                            OnePlus 11 5G  ₹54,999    89.0
# 1                OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2                    Samsung Galaxy A14 5G  ₹16,499    75.0
# 3                     Motorola Moto G62 5G  ₹14,999    81.0
# 4                       Realme 10 Pro Plus  ₹24,999    82.0
# 5  Samsung Galaxy F23 5G (6GB RAM + 128GB)  ₹16,999    80.0
# 6                          Apple iPhone 14  ₹65,999    81.0
# 7            Xiaomi Redmi Note 12 Pro Plus  ₹29,999    86.0
# 8                          Nothing Phone 1  ₹26,749    85.0
# 9                       OnePlus Nord 2T 5G  ₹28,999    84.0
#
#                                               sim  \
# 0         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
mobile['brand'].value_counts()
# Out:
# Xiaomi       135
# Samsung      132
# Vivo         111
# Realme        97
# OPPO          62
# Motorola      52
# Apple         47
# OnePlus       42
# Tecno         33
# iQOO          32
# Infinix       29
# Poco          28
# Oppo          26
# Nokia         24
# Huawei        16
# Google        14
# POCO          13
# Honor         13
# itel          10
# Sony           9
# Asus           7
# Nubia          6
# Nothing        5
# Jio            5
# iKall          4
# Lava           4
# Itel           3
# Lyf            3
# Oukitel        3
# LG             3
# Redmi          3
# Micromax       3
# Gionee         3
# Letv           3
# ZTE            2
# Lenovo         2
# Doogee         2
# Royole         2
# BlackZone      1
# Tesla          1
# TCL            1
# CAT            1
# Sharp          1
# Blackview      1
# DIZO           1
# BLU            1
# Leitz          1
# Eunity         1
# Cola           1
# Vertu          1
# Duoqin         1
# LeEco          1
# ...

# %%
mobile['model']= mobile['model'].apply(lambda x: " ".join(x.split()[1:]))

# %%
mobile.head()
# Out:
#                model    price  rating  \
# 0              11 5G  ₹54,999    89.0
# 1  Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Galaxy A14 5G  ₹16,499    75.0
# 3        Moto G62 5G  ₹14,999    81.0
# 4        10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %%
mobile['price'] = mobile['price'].apply(lambda x:x.replace('₹',''))

# %%
 mobile['price']= mobile['price'].apply(lambda x:x.replace(',','')).astype('int32')

# %%
mobile['rating'] = mobile['rating'].apply(lambda x: (x))

# %%
mobile['rating']
# Out:
# 0       89.0
# 1       81.0
# 2       75.0
# 3       81.0
# 4       82.0
#         ...
# 1015    83.0
# 1016    75.0
# 1017    85.0
# 1018    80.0
# 1019    74.0
# Name: rating, Length: 1003, dtype: float64

# %%
mobile.corr()
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_6028\3299322897.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mobile.corr()
#            price    rating
# price   1.000000  0.250233
# rating  0.250233  1.000000

# %%
mobile.head()
# Out:
#                model  price  rating                                      sim  \
# 0              11 5G  54999    89.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1  Nord CE 2 Lite 5G  19989    81.0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2      Galaxy A14 5G  16499    75.0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3        Moto G62 5G  14999    81.0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4        10 Pro Plus  24999    82.0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
# ...

# %%
mobile['num_sim'] = mobile['sim'].apply(lambda x: " ".join(x.split()[0:2]) )

# %%
def simtype(text):
    if ' 5G' in text.split(','):
        return 5
    elif ' 4G' in text.split(','):
        return 4
    else:
        return 3

# %%
mobile['network_type'] = mobile['sim'].apply(simtype)

# %%
mobile['NFC'] = mobile['sim'].apply(lambda x: 1 if 'NFC' in x else 0)

# %%
mobile.shape
# Out:
# (1003, 15)

# %%
mobile.head()
# Out:
#                model  price  rating                                      sim  \
# 0              11 5G  54999    89.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1  Nord CE 2 Lite 5G  19989    81.0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2      Galaxy A14 5G  16499    75.0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3        Moto G62 5G  14999    81.0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4        10 Pro Plus  24999    82.0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
# ...

# %%
mobile.drop(columns=['sim'],inplace=True)

# %%
mobile['processor_brand'] = mobile['processor'].apply(lambda x: x.split()[0])

# %%
mobile['processor_brand'].value_counts()
# Out:
# Snapdragon    411
# Helio         200
# Dimensity     177
# Exynos         49
# Bionic         39
# Unisoc         27
# Tiger          24
# Octa           14
# Google          9
# No              8
# Kirin           7
# Quad            6
# Qualcomm        5
# A13             5
# Spreadtrum      4
# SC9863A,        2
# Helio,          2
# SC6531E,        1
# 48              1
# 256             1
# Single          1
# Samsung         1
# (28             1
# 1               1
# 32              1
# Fusion          1
# Sanpdragon      1
# Dual            1
# Unisoc,         1
# Apple           1
# 8               1
# Name: processor_brand, dtype: int64

# %%
def proccer(text):
    if text=='Octa' or text=='Quad':
        return 'others'
    elif text=='Samsung':
        return 'Exynos'
    elif text == 'Apple':
        return 'Bionic'
    elif text =='Helio,':
        return 'Helio'
    elif text =='Sanpdragon':
        return "Snapdragon"
    elif text =='Qualcomm':
        return 'Snapdragon'
    else:
        return text

# %%
mobile['processor_brand'] = mobile['processor_brand'].apply(proccer)

# %%
proc_brand = mobile['processor_brand'].value_counts()

# %%
proc_brand = proc_brand[13:].index

# %%
proc_brand
# Out:
# Index(['SC9863A,', 'SC6531E,', '48', '256', 'Single', '(28', 'Unisoc,', '32',
#        'Fusion', '1', 'Dual', '8'],
#       dtype='object')

# %%
mobile['processor_brand'] = mobile['processor_brand'].apply(lambda x: 'others' if x in proc_brand else x)

# %%
mobile['processor_brand'].value_counts()
# Out:
# Snapdragon    417
# Helio         202
# Dimensity     177
# Exynos         50
# Bionic         40
# others         33
# Unisoc         27
# Tiger          24
# Google          9
# No              8
# Kirin           7
# A13             5
# Spreadtrum      4
# Name: processor_brand, dtype: int64

# %%
mobile.head()
# Out:
#                model  price  rating  \
# 0              11 5G  54999    89.0
# 1  Nord CE 2 Lite 5G  19989    81.0
# 2      Galaxy A14 5G  16499    75.0
# 3        Moto G62 5G  14999    81.0
# 4        10 Pro Plus  24999    82.0
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
# ...

# %%
def num_cores(text):
    if 'Dual' in text:
        return 2
    elif 'Quad' in text:
        return 4
    elif 'Octa' in text:
        return 8
    elif 'Hexa' in text:
        return 6
    else:
        return 0

# %%
mobile['num_cores'] = mobile['processor'].apply(num_cores)

# %%
mobile['num_cores'].value_counts()
# Out:
# 8    899
# 6     39
# 4     39
# 0     24
# 2      2
# Name: num_cores, dtype: int64

# %%
mobile['processor'] = mobile['processor'].apply(lambda x:x.replace(',',''))

# %%
mobile['clock_speed'] = mobile['processor'].apply(lambda x:" ".join(x.split()[-3:]))

# %%
mobile['clock_speed'].apply(lambda x:x.split()[0])
# Out:
# 0        3.2
# 1        2.2
# 2        2.4
# 3        2.2
# 4        2.6
#         ...
# 1015       3
# 1016     2.2
# 1017    2.85
# 1018     2.2
# 1019    Octa
# Name: clock_speed, Length: 1003, dtype: object

# %%
mobile['clock_speed'].value_counts()
# Out:
# 2 GHz Processor        146
# 2.2 GHz Processor      135
# 2.4 GHz Processor      128
# 3.2 GHz Processor       94
# 2.3 GHz Processor       86
# 3 GHz Processor         53
# 2.84 GHz Processor      36
# Octa Core Processor     28
# 2.05 GHz Processor      28
# 1.8 GHz Processor       23
# 2.5 GHz Processor       23
# 1.6 GHz Processor       20
# 2.85 GHz Processor      19
# 3.22 GHz Processor      18
# 3.1 GHz Processor       15
# 2.6 GHz Processor       14
# 2.9 GHz Processor       13
# 1.3 GHz Processor       11
# 1.82 GHz Processor      10
# 2.73 GHz Processor       9
# 2.8 GHz Processor        9
# 2.36 GHz Processor       8
# 3.05 GHz Processor       8
# Hexa Core Processor      8
# 1.4 GHz Processor        5
# 2.65 GHz Processor       5
# 2.7 GHz Processor        5
# No 3G                    4
# 1.5 GHz Processor        4
# No Wifi                  4
# Bionic A16               4
# 1 GHz Processor          3
# 1.1 GHz Processor        3
# 2.96 GHz Processor       3
# ...

# %%
temp = ["Octa","Hexa","No","Bionic","Unisoc","16","128","512","Apple","32","Helio","Snapdragon"]

# %%
mobile['clock_speed'] = mobile['clock_speed'].apply(lambda x:'Others' if x.split()[0] in temp else x)

# %%
mobile['clock_speed'].value_counts()
# Out:
# 2 GHz Processor       146
# 2.2 GHz Processor     135
# 2.4 GHz Processor     128
# 3.2 GHz Processor      94
# 2.3 GHz Processor      86
# Others                 57
# 3 GHz Processor        53
# 2.84 GHz Processor     36
# 2.05 GHz Processor     28
# 2.5 GHz Processor      23
# 1.8 GHz Processor      23
# 1.6 GHz Processor      20
# 2.85 GHz Processor     19
# 3.22 GHz Processor     18
# 3.1 GHz Processor      15
# 2.6 GHz Processor      14
# 2.9 GHz Processor      13
# 1.3 GHz Processor      11
# 1.82 GHz Processor     10
# 2.73 GHz Processor      9
# 2.8 GHz Processor       9
# 3.05 GHz Processor      8
# 2.36 GHz Processor      8
# 2.7 GHz Processor       5
# 1.4 GHz Processor       5
# 2.65 GHz Processor      5
# 1.5 GHz Processor       4
# 1.1 GHz Processor       3
# 1 GHz Processor         3
# 2.96 GHz Processor      3
# 2.86 GHz Processor      3
# 3.13 GHz Processor      2
# 2.35 GHz Processor      1
# 2.37 GHz Processor      1
# 1.99 GHz Processor      1
# ...

# %%
mobile.head()
# Out:
#                model  price  rating  \
# 0              11 5G  54999    89.0
# 1  Nord CE 2 Lite 5G  19989    81.0
# 2      Galaxy A14 5G  16499    75.0
# 3        Moto G62 5G  14999    81.0
# 4        10 Pro Plus  24999    82.0
#
#                                        processor                        ram  \
# 0  Snapdragon 8 Gen2 Octa Core 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695 Octa Core 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330 Octa Core 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695 Octa Core 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080 Octa Core 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
# ...

# %%
mobile.drop(columns=['processor'],inplace = True)

# %%
mobile.head()
# Out:
#                model  price  rating                        ram  \
# 0              11 5G  54999    89.0  12 GB RAM, 256 GB inbuilt
# 1  Nord CE 2 Lite 5G  19989    81.0   6 GB RAM, 128 GB inbuilt
# 2      Galaxy A14 5G  16499    75.0    4 GB RAM, 64 GB inbuilt
# 3        Moto G62 5G  14999    81.0   6 GB RAM, 128 GB inbuilt
# 4        10 Pro Plus  24999    82.0   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# ...

# %%
mobile.corr()
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_6028\3299322897.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mobile.corr()
#                  price    rating  network_type       NFC  num_cores
# price         1.000000  0.250233      0.317811  0.477956   0.005950
# rating        0.250233  1.000000      0.540128  0.441416   0.107290
# network_type  0.317811  0.540128      1.000000  0.488645   0.267602
# NFC           0.477956  0.441416      0.488645  1.000000   0.073998
# num_cores     0.005950  0.107290      0.267602  0.073998   1.000000

# %%
mobile['ram'].apply(lambda x:x.split())
# Out:
# 0       [12, GB, RAM,, 256, GB, inbuilt]
# 1        [6, GB, RAM,, 128, GB, inbuilt]
# 2         [4, GB, RAM,, 64, GB, inbuilt]
# 3        [6, GB, RAM,, 128, GB, inbuilt]
# 4        [6, GB, RAM,, 128, GB, inbuilt]
#                       ...
# 1015     [8, GB, RAM,, 128, GB, inbuilt]
# 1016     [6, GB, RAM,, 128, GB, inbuilt]
# 1017     [8, GB, RAM,, 256, GB, inbuilt]
# 1018     [6, GB, RAM,, 128, GB, inbuilt]
# 1019     [8, GB, RAM,, 128, GB, inbuilt]
# Name: ram, Length: 1003, dtype: object

# %%
mobile['ram_x'] = mobile['ram'].apply(lambda x: " ".join(x.split()[0:2]))

# %%
mobile['ram_x'].value_counts()
# Out:
# 8 GB           339
# 6 GB           234
# 4 GB           216
# 12 GB           85
# 3 GB            54
# 2 GB            32
# 16 GB            9
# 1 GB             8
# 64 MB            3
# Unisoc T107      3
# 512 MB           3
# 64 GB            2
# 18 GB            2
# T117             2
# 1200 mAh         2
# 48 MB            1
# 1800 mAh         1
# 4 MB             1
# 512 GB           1
# 32 MB            1
# 4 inches,        1
# 8 MB             1
# Dual Core,       1
# No Wifi          1
# Name: ram_x, dtype: int64

# %%
temp = ['Unisoc','T117','1200','1800','48','512','Dual','No']

# %%
mobile['ram_x'] = mobile['ram_x'].apply(lambda x:"others" if x.split()[0] in temp else x)

# %%
mobile.sample(5)
# Out:
#                     model  price  rating                              ram  \
# 167  10 (8GB RAM + 128GB)  16999    79.0         8 GB RAM, 128 GB inbuilt
# 291            Galaxy M13  12999    75.0         6 GB RAM, 128 GB inbuilt
# 754  iPod Touch (7th Gen)  18900    78.0  4 inches, 640 x 1136 px Display
# 965                  Y12a   9999    65.0          3 GB RAM, 32 GB inbuilt
# 992                    C2   6999    78.0          2 GB RAM, 16 GB inbuilt
#
#                                      battery  \
# 167  5000 mAh Battery with 33W Fast Charging
# 291  6000 mAh Battery with 15W Fast Charging
# 754          8 MP Rear & 1.2 MP Front Camera
# 965                         5000 mAh Battery
# 992                         4000 mAh Battery
#
#                                                display  \
# 167  6.4 inches, 1080 x 2400 px, 90 Hz Display with...
# 291  6.6 inches, 1080 x 2400 px Display with Water ...
# 754                                            iOS v12
# ...

# %%
mobile['temp'] = mobile['ram'].apply(lambda x: x.split(',')[-1])

# %%
 mobile['storage'] = mobile['temp'].apply(lambda x: " ".join(x.split()[0:2]))

# %%
 mobile['storage'].value_counts()
# Out:
# 128 GB         523
# 64 GB          193
# 256 GB         157
# 32 GB           67
# 512 GB          22
# 16 GB           12
# 1 TB             5
# 4 GB             3
# Unisoc T107      3
# 128 MB           3
# 8 GB             2
# 1200 mAh         2
# T117             2
# 500 MHz          1
# 16 MB            1
# 640 x            1
# 32 MB            1
# 48 MB            1
# 4 MB             1
# 512 MB           1
# 1800 mAh         1
# No Wifi          1
# Name: storage, dtype: int64

# %%
temp = ['Unisoc','T117','1200','500','640','No','1800']

# %%
 mobile['storage']=  mobile['storage'].apply(lambda x:"others" if x.split()[0] in temp else x)

# %%
 mobile['storage'].value_counts()
# Out:
# 128 GB    523
# 64 GB     193
# 256 GB    157
# 32 GB      67
# 512 GB     22
# 16 GB      12
# others     11
# 1 TB        5
# 4 GB        3
# 128 MB      3
# 8 GB        2
# 512 MB      1
# 16 MB       1
# 32 MB       1
# 48 MB       1
# 4 MB        1
# Name: storage, dtype: int64

# %%
mobile.head()
# Out:
#                model  price  rating                        ram  \
# 0              11 5G  54999    89.0  12 GB RAM, 256 GB inbuilt
# 1  Nord CE 2 Lite 5G  19989    81.0   6 GB RAM, 128 GB inbuilt
# 2      Galaxy A14 5G  16499    75.0    4 GB RAM, 64 GB inbuilt
# 3        Moto G62 5G  14999    81.0   6 GB RAM, 128 GB inbuilt
# 4        10 Pro Plus  24999    82.0   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# ...

# %%
mobile.drop(columns=['ram','temp'],inplace = True)

# %%
mobile.sample(5)
# Out:
#                     model  price  rating  \
# 714             Moto G 5G  19990    82.0
# 600                  Y20G  13990    69.0
# 621  8i (6GB RAM + 128GB)  13999    77.0
# 183              Moto X40  39999    89.0
# 652                X7 Max  26999    84.0
#
#                                       battery  \
# 714   5000 mAh Battery with 20W Fast Charging
# 600   5000 mAh Battery with 18W Fast Charging
# 621   5000 mAh Battery with 18W Fast Charging
# 183  4600 mAh Battery with 125W Fast Charging
# 652   4500 mAh Battery with 50W Fast Charging
#
#                                                display  \
# 714  6.67 inches, 1080 x 2400 px Display with Punch...
# 600  6.51 inches, 720 x 1600 px Display with Water ...
# 621  6.6 inches, 1080 x 2412 px, 120 Hz Display wit...
# 183         6.7 inches, 1080 x 2400 px, 165 Hz Display
# 652  6.43 inches, 1080 x 2400 px, 120 Hz Display wi...
#
#                                                 camera  \
# ...

# %%
mobile['battery'].apply(lambda x: x.split())
# Out:
# 0        [5000, mAh, Battery, with, 100W, Fast, Charging]
# 1         [5000, mAh, Battery, with, 33W, Fast, Charging]
# 2         [5000, mAh, Battery, with, 15W, Fast, Charging]
# 3              [5000, mAh, Battery, with, Fast, Charging]
# 4         [5000, mAh, Battery, with, 67W, Fast, Charging]
#                               ...
# 1015    [5000, mAh, Battery, with, 68.2W, Fast, Charging]
# 1016    [5000, mAh, Battery, with, 22.5W, Fast, Charging]
# 1017      [5080, mAh, Battery, with, 67W, Fast, Charging]
# 1018           [5000, mAh, Battery, with, Fast, Charging]
# 1019           [5000, mAh, Battery, with, Fast, Charging]
# Name: battery, Length: 1003, dtype: object

# %%
mobile['battery'].apply(lambda x: x.split()[0])
# Out:
# 0       5000
# 1       5000
# 2       5000
# 3       5000
# 4       5000
#         ...
# 1015    5000
# 1016    5000
# 1017    5080
# 1018    5000
# 1019    5000
# Name: battery, Length: 1003, dtype: object

# %%
mobile['battery_cap'] = mobile['battery'].apply(lambda x: x.split()[0])

# %%
mobile['battery_cap'].value_counts()
# Out:
# 5000    487
# 4500     97
# 6000     60
# 4000     42
# 4700     27
#        ...
# 3060      1
# 4355      1
# 2230      1
# 4870      1
# 8000      1
# Name: battery_cap, Length: 103, dtype: int64

# %%
mobile['battery'].apply(lambda x: " ".join(x.split()[-3:]))
# Out:
# 0        100W Fast Charging
# 1         33W Fast Charging
# 2         15W Fast Charging
# 3        with Fast Charging
# 4         67W Fast Charging
#                ...
# 1015    68.2W Fast Charging
# 1016    22.5W Fast Charging
# 1017      67W Fast Charging
# 1018     with Fast Charging
# 1019     with Fast Charging
# Name: battery, Length: 1003, dtype: object

# %%
mobile['charging'] = mobile['battery'].apply(lambda x: " ".join(x.split()[-3:]))

# %%
mobile['charging'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        100W Fast Charging
# 1         33W Fast Charging
# 2         15W Fast Charging
# 3        with Fast Charging
# 4         67W Fast Charging
#                ...
# 1015    68.2W Fast Charging
# 1016    22.5W Fast Charging
# 1017      67W Fast Charging
# 1018     with Fast Charging
# 1019     with Fast Charging
# Name: charging, Length: 1003, dtype: object>

# %%
mobile['charging'].apply(lambda x:(x.split()[0:2]))
# Out:
# 0        [100W, Fast]
# 1         [33W, Fast]
# 2         [15W, Fast]
# 3        [with, Fast]
# 4         [67W, Fast]
#             ...
# 1015    [68.2W, Fast]
# 1016    [22.5W, Fast]
# 1017      [67W, Fast]
# 1018     [with, Fast]
# 1019     [with, Fast]
# Name: charging, Length: 1003, dtype: object

# %%
mobile['charging'].value_counts()
# Out:
# 33W Fast Charging      152
# 18W Fast Charging      128
# 5000 mAh Battery        74
# with Fast Charging      68
# 67W Fast Charging       65
#                       ...
# 1450 mAh Battery         1
# 180W Fast Charging       1
# 2150 mAh Battery         1
# 4450 mAh Battery         1
# 68.2W Fast Charging      1
# Name: charging, Length: 77, dtype: int64

# %%
mobile.head()
# Out:
#                model  price  rating                                   battery  \
# 0              11 5G  54999    89.0  5000 mAh Battery with 100W Fast Charging
# 1  Nord CE 2 Lite 5G  19989    81.0   5000 mAh Battery with 33W Fast Charging
# 2      Galaxy A14 5G  16499    75.0   5000 mAh Battery with 15W Fast Charging
# 3        Moto G62 5G  14999    81.0       5000 mAh Battery with Fast Charging
# 4        10 Pro Plus  24999    82.0   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# ...

# %%
mobile['charging']=mobile['charging'].apply(lambda x: x.replace('with',''))

# %%
# mobile.drop(columns=['battery','tempc'],inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[255], line 1
# ----> 1 mobile.drop(columns=['battery','tempc'],inplace = True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
mobile.drop(columns=['display'],inplace = True)

# %%
mobile.head()
# Out:
#                model  price  rating                                   battery  \
# 0              11 5G  54999    89.0  5000 mAh Battery with 100W Fast Charging
# 1  Nord CE 2 Lite 5G  19989    81.0   5000 mAh Battery with 33W Fast Charging
# 2      Galaxy A14 5G  16499    75.0   5000 mAh Battery with 15W Fast Charging
# 3        Moto G62 5G  14999    81.0       5000 mAh Battery with Fast Charging
# 4        10 Pro Plus  24999    82.0   5000 mAh Battery with 67W Fast Charging
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os     brand  num_sim  \
# 0         Memory Card Not Supported  Android v13   OnePlus        2
# ...

# %%
mobile['camera_first'] = mobile['camera'].apply(lambda x:x.split('+')[0])

# %%
mobile['camera_first'] = mobile['camera_first'].apply(lambda x:x.replace('MP',''))

# %%
mobile['camera_first'] = mobile['camera_first'].apply(lambda x:x.split()[0])

# %%
mobile['camera_first'].value_counts()
# Out:
# 50          318
# 64          175
# 13          116
# 48          113
# 108          79
# 12           44
# 8            39
# Foldable     20
# 200          18
# 16           17
# Memory       14
# Dual          8
# 5             6
# 2             5
# 12.2          4
# 0.3           4
# 54            3
# 50.3          3
# 20            3
# 2.4           3
# No            3
# 2.8           2
# 24            2
# 1.8           1
# 47.2          1
# 40            1
# 1.77          1
# Name: camera_first, dtype: int64

# %%
temp = ['Foldable','Memory','Dual','No']
mobile['camera_first'] = mobile['camera_first'].apply(lambda x:'others' if x in temp else x)

# %%
mobile['camera_first'].value_counts()
# Out:
# 50        318
# 64        175
# 13        116
# 48        113
# 108        79
# others     45
# 12         44
# 8          39
# 200        18
# 16         17
# 5           6
# 2           5
# 12.2        4
# 0.3         4
# 20          3
# 2.4         3
# 54          3
# 50.3        3
# 2.8         2
# 24          2
# 1.8         1
# 47.2        1
# 40          1
# 1.77        1
# Name: camera_first, dtype: int64

# %%
mobile.head()
# Out:
#                model  price  rating                                   battery  \
# 0              11 5G  54999    89.0  5000 mAh Battery with 100W Fast Charging
# 1  Nord CE 2 Lite 5G  19989    81.0   5000 mAh Battery with 33W Fast Charging
# 2      Galaxy A14 5G  16499    75.0   5000 mAh Battery with 15W Fast Charging
# 3        Moto G62 5G  14999    81.0       5000 mAh Battery with Fast Charging
# 4        10 Pro Plus  24999    82.0   5000 mAh Battery with 67W Fast Charging
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os     brand  num_sim  \
# 0         Memory Card Not Supported  Android v13   OnePlus        2
# ...

# %%
mobile['camera_front']=mobile['camera'].apply(lambda x:x.split("&")[-1])

# %%
mobile['camera_front']=mobile['camera_front'].apply(lambda x:x.split()[0])

# %%
mobile['camera_front'].value_counts()
# Out:
# 16          303
# 8           178
# 32          147
# 5           119
# 13           41
# 12           40
# 20           35
# Foldable     20
# 10           18
# Memory       14
# 50           12
# 60           10
# Dual          8
# 44            8
# 2             8
# 40            6
# 0.3           6
# 7             4
# No            3
# 2.4           3
# 24            3
# 25            3
# 11.1          2
# 2.8           2
# 48            2
# 10.8          2
# 12.6          1
# 10.1          1
# 108           1
# 1.8           1
# 2.1           1
# 1.77          1
# Name: camera_front, dtype: int64

# %%
temp = ['Foldable','Memory','Dual','No']
mobile['camera_front'] = mobile['camera_front'].apply(lambda x:'others' if x in temp else x)

# %%
mobile['camera_front'].value_counts()
# Out:
# 16        303
# 8         178
# 32        147
# 5         119
# others     45
# 13         41
# 12         40
# 20         35
# 10         18
# 50         12
# 60         10
# 44          8
# 2           8
# 40          6
# 0.3         6
# 7           4
# 25          3
# 24          3
# 2.4         3
# 10.8        2
# 48          2
# 2.8         2
# 11.1        2
# 108         1
# 2.1         1
# 1.8         1
# 10.1        1
# 12.6        1
# 1.77        1
# Name: camera_front, dtype: int64

# %%
mobile.drop(columns=['camera','card'],inplace = True)

# %%
mobile.head()
# Out:
#                model  price  rating                                   battery  \
# 0              11 5G  54999    89.0  5000 mAh Battery with 100W Fast Charging
# 1  Nord CE 2 Lite 5G  19989    81.0   5000 mAh Battery with 33W Fast Charging
# 2      Galaxy A14 5G  16499    75.0   5000 mAh Battery with 15W Fast Charging
# 3        Moto G62 5G  14999    81.0       5000 mAh Battery with Fast Charging
# 4        10 Pro Plus  24999    82.0   5000 mAh Battery with 67W Fast Charging
#
#             os     brand  num_sim  network_type  NFC processor_brand  \
# 0  Android v13   OnePlus        2             5    1      Snapdragon
# 1  Android v12   OnePlus        2             5    0      Snapdragon
# 2  Android v13   Samsung        2             5    0          Exynos
# 3  Android v12  Motorola        2             5    0      Snapdragon
# 4  Android v13    Realme        2             5    0       Dimensity
#
#    num_cores        clock_speed  ram_x storage battery_cap  \
# ...

# %%
mobile['os'] = mobile['os'].apply(lambda x:x.split()[0])

# %%
mobile['os'].value_counts()
# Out:
# Android      701
# No           192
# Bluetooth     38
# iOS           33
# Memory        21
# Browser        4
# HarmonyOS      2
# Hongmeng       2
# RTOS           2
# Harmony        2
# EMUI           2
# 0.3            1
# KAI            1
# Pragati        1
# 1.3            1
# Name: os, dtype: int64

# %%
temp = ['Android','iOS','HarmonyOS','EMUI']
mobile['os'] = mobile['os'].apply(lambda x:'others' if x not in temp else x)

# %%
mobile['os'].value_counts()
# Out:
# Android      701
# others       265
# iOS           33
# HarmonyOS      2
# EMUI           2
# Name: os, dtype: int64

# %%
mobile.head()

# %%
mobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1003 entries, 0 to 1019
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   model            1003 non-null   object
#  1   price            1003 non-null   int32
#  2   rating           1003 non-null   float64
#  3   battery          1003 non-null   object
#  4   os               1003 non-null   object
#  5   brand            1003 non-null   object
#  6   num_sim          1003 non-null   int64
#  7   network_type     1003 non-null   int64
#  8   NFC              1003 non-null   int64
#  9   processor_brand  1003 non-null   object
#  10  num_cores        1003 non-null   int64
#  11  clock_speed      1003 non-null   object
#  12  ram_x            1003 non-null   object
#  13  storage          1003 non-null   object
#  14  battery_cap      1003 non-null   object
#  15  charging         1003 non-null   object
#  16  camera_first     1003 non-null   object
# ...

# %%
mobile['num_sim'].value_counts()
# Out:
# 2    986
# 1     16
# 0      1
# Name: num_sim, dtype: int64

# %%
def num_sim(text):
    text = text.split()[0]
    if text == "Dual":
        return 2
    elif text == 'Single':
        return 1
    else:
        return 0

# %%
mobile['num_sim'] = mobile['num_sim'].apply(num_sim)

# %%
mobile['num_sim'].value_counts()
# Out:
# 2    986
# 1     16
# 0      1
# Name: num_sim, dtype: int64

# %%
mobile.drop(columns=['battery'],inplace = True)

# %%
mobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1003 entries, 0 to 1019
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   model            1003 non-null   object
#  1   price            1003 non-null   int32
#  2   rating           1003 non-null   float64
#  3   os               1003 non-null   object
#  4   brand            1003 non-null   object
#  5   num_sim          1003 non-null   int64
#  6   network_type     1003 non-null   int64
#  7   NFC              1003 non-null   int64
#  8   processor_brand  1003 non-null   object
#  9   num_cores        1003 non-null   int64
#  10  clock_speed      1003 non-null   object
#  11  ram_x            1003 non-null   object
#  12  storage          1003 non-null   object
#  13  battery_cap      1003 non-null   object
#  14  charging         1003 non-null   object
#  15  camera_first     1003 non-null   object
#  16  camera_front     1003 non-null   object
# ...

# %%
mobile.head()
# Out:
#                model  price  rating       os     brand  num_sim  network_type  \
# 0              11 5G  54999    89.0  Android   OnePlus        2             5
# 1  Nord CE 2 Lite 5G  19989    81.0  Android   OnePlus        2             5
# 2      Galaxy A14 5G  16499    75.0  Android   Samsung        2             5
# 3        Moto G62 5G  14999    81.0  Android  Motorola        2             5
# 4        10 Pro Plus  24999    82.0  Android    Realme        2             5
#
#    NFC processor_brand  num_cores        clock_speed  ram_x storage  \
# 0    1      Snapdragon          8  3.2 GHz Processor  12 GB  256 GB
# 1    0      Snapdragon          8  2.2 GHz Processor   6 GB  128 GB
# 2    0          Exynos          8  2.4 GHz Processor   4 GB   64 GB
# 3    0      Snapdragon          8  2.2 GHz Processor   6 GB  128 GB
# 4    0       Dimensity          8  2.6 GHz Processor   6 GB  128 GB
#
#   battery_cap            charging camera_first camera_front
# ...

# %%
mobile['camera_front'].value_counts()
# Out:
# 16        303
# 8         178
# 32        147
# 5         119
# others     45
# 13         41
# 12         40
# 20         35
# 10         18
# 50         12
# 60         10
# 44          8
# 2           8
# 40          6
# 0.3         6
# 7           4
# 25          3
# 24          3
# 2.4         3
# 10.8        2
# 48          2
# 2.8         2
# 11.1        2
# 108         1
# 2.1         1
# 1.8         1
# 10.1        1
# 12.6        1
# 1.77        1
# Name: camera_front, dtype: int64

# %%
mobile.corr()
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_6028\3299322897.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mobile.corr()
#                  price    rating   num_sim  network_type       NFC  num_cores
# price         1.000000  0.250233 -0.156183      0.317811  0.477956   0.005950
# rating        0.250233  1.000000  0.011380      0.540128  0.441416   0.107290
# num_sim      -0.156183  0.011380  1.000000      0.051343 -0.072138   0.125728
# network_type  0.317811  0.540128  0.051343      1.000000  0.488645   0.267602
# NFC           0.477956  0.441416 -0.072138      0.488645  1.000000   0.073998
# num_cores     0.005950  0.107290  0.125728      0.267602  0.073998   1.000000

# %%
mobile.head()
# Out:
#                model  price  rating       os     brand  num_sim  network_type  \
# 0              11 5G  54999    89.0  Android   OnePlus        2             5
# 1  Nord CE 2 Lite 5G  19989    81.0  Android   OnePlus        2             5
# 2      Galaxy A14 5G  16499    75.0  Android   Samsung        2             5
# 3        Moto G62 5G  14999    81.0  Android  Motorola        2             5
# 4        10 Pro Plus  24999    82.0  Android    Realme        2             5
#
#    NFC processor_brand  num_cores        clock_speed  ram_x storage  \
# 0    1      Snapdragon          8  3.2 GHz Processor  12 GB  256 GB
# 1    0      Snapdragon          8  2.2 GHz Processor   6 GB  128 GB
# 2    0          Exynos          8  2.4 GHz Processor   4 GB   64 GB
# 3    0      Snapdragon          8  2.2 GHz Processor   6 GB  128 GB
# 4    0       Dimensity          8  2.6 GHz Processor   6 GB  128 GB
#
#   battery_cap            charging camera_first camera_front
# ...

# %%
sns.barplot(x = mobile['os'], y = mobile['price'])
# Out:
# <Axes: xlabel='os', ylabel='price'>

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize = (15,8))
plt.xticks(rotation = 'vertical')
sns.barplot(x = mobile['brand'], y = mobile['price'])
# Out:
# <Axes: xlabel='brand', ylabel='price'>

# %%
mobile.head()
# Out:
#                model  price  rating       os     brand  num_sim  network_type  \
# 0              11 5G  54999    89.0  Android   OnePlus        2             5
# 1  Nord CE 2 Lite 5G  19989    81.0  Android   OnePlus        2             5
# 2      Galaxy A14 5G  16499    75.0  Android   Samsung        2             5
# 3        Moto G62 5G  14999    81.0  Android  Motorola        2             5
# 4        10 Pro Plus  24999    82.0  Android    Realme        2             5
#
#    NFC processor_brand  num_cores        clock_speed  ram_x storage  \
# 0    1      Snapdragon          8  3.2 GHz Processor  12 GB  256 GB
# 1    0      Snapdragon          8  2.2 GHz Processor   6 GB  128 GB
# 2    0          Exynos          8  2.4 GHz Processor   4 GB   64 GB
# 3    0      Snapdragon          8  2.2 GHz Processor   6 GB  128 GB
# 4    0       Dimensity          8  2.6 GHz Processor   6 GB  128 GB
#
#   battery_cap            charging camera_first camera_front
# ...

# %%
plt.figure(figsize = (10,6))
plt.xticks(rotation = 'vertical')
sns.barplot(x = mobile['processor_brand'], y = mobile['price'])
# Out:
# <Axes: xlabel='processor_brand', ylabel='price'>

# %%
plt.figure(figsize = (10,6))
plt.xticks(rotation = 'vertical')
sns.barplot(x = mobile['ram_x'], y = mobile['price'])
# Out:
# <Axes: xlabel='ram_x', ylabel='price'>

# %%
plt.figure(figsize = (10,6))
plt.xticks(rotation = 'vertical')
sns.barplot(x = mobile['storage'], y = mobile['price'])
# Out:
# <Axes: xlabel='storage', ylabel='price'>

# %%
mobile.head()
# Out:
#                model  price  rating       os     brand  num_sim  network_type  \
# 0              11 5G  54999    89.0  Android   OnePlus        2             5
# 1  Nord CE 2 Lite 5G  19989    81.0  Android   OnePlus        2             5
# 2      Galaxy A14 5G  16499    75.0  Android   Samsung        2             5
# 3        Moto G62 5G  14999    81.0  Android  Motorola        2             5
# 4        10 Pro Plus  24999    82.0  Android    Realme        2             5
#
#    NFC processor_brand  num_cores        clock_speed  ram_x storage  \
# 0    1      Snapdragon          8  3.2 GHz Processor  12 GB  256 GB
# 1    0      Snapdragon          8  2.2 GHz Processor   6 GB  128 GB
# 2    0          Exynos          8  2.4 GHz Processor   4 GB   64 GB
# 3    0      Snapdragon          8  2.2 GHz Processor   6 GB  128 GB
# 4    0       Dimensity          8  2.6 GHz Processor   6 GB  128 GB
#
#   battery_cap            charging camera_first camera_front
# ...

# %%
sns.scatterplot(x = mobile['rating'], y = mobile['price'])
# Out:
# <Axes: xlabel='rating', ylabel='price'>

# %%
plt.figure(figsize = (10,6))
plt.xticks(rotation = 'vertical')
sns.barplot(x = mobile['NFC'], y = mobile['price'])
# Out:
# <Axes: xlabel='NFC', ylabel='price'>

# %%
sns.heatmap(mobile.corr())
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_6028\2877319868.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(mobile.corr())
# <Axes: >

# %%
sns.displot(mobile['price'])

# %%
sns.displot((np.log(mobile['price'])))

# %%
mobile['price'] = mobile['price'].apply(lambda x: np.log(x))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# %%
mobile.head(2)
# Out:
#                model      price  rating       os    brand  num_sim  \
# 0              11 5G  10.915070    89.0  Android  OnePlus        2
# 1  Nord CE 2 Lite 5G   9.902937    81.0  Android  OnePlus        2
#
#    network_type  NFC processor_brand  num_cores        clock_speed  ram_x  \
# 0             5    1      Snapdragon          8  3.2 GHz Processor  12 GB
# 1             5    0      Snapdragon          8  2.2 GHz Processor   6 GB
#
#   storage battery_cap            charging camera_first camera_front
# 0  256 GB        5000  100W Fast Charging           50           16
# 1  128 GB        5000   33W Fast Charging           64           16

# %%
x = mobile.drop(columns=['price'])

# %%
y = mobile['price']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x, y, test_size=0.2,random_state=2)

# %%
xtrain
# Out:
#                             model  rating       os     brand  num_sim  \
# 175     Z6 Lite (6GB RAM + 128GB)    79.0  Android      iQOO        2
# 512                 Galaxy F42 5G    80.0  Android   Samsung        2
# 912                     Nord N100    68.0  Android   OnePlus        2
# 375               Galaxy S10 Plus    81.0  Android   Samsung        2
# 200                          A77s    76.0  Android      OPPO        2
# ..                            ...     ...      ...       ...      ...
# 536                           C31    62.0  Android     Nokia        2
# 587  Galaxy A13 (6GB RAM + 128GB)    78.0  Android   Samsung        2
# 494    Moto E32s (4GB RAM + 64GB)    67.0  Android  Motorola        2
# 528                      Y73 2021    80.0  Android      Vivo        2
# 168                       9 SE 5G    83.0   others      iQOO        2
#
#      network_type  NFC processor_brand  num_cores         clock_speed ram_x  \
# ...

# %%
xtest
# Out:
#                             model  rating       os    brand  num_sim  \
# 37            Galaxy S22 Ultra 5G    78.0   others  Samsung        2
# 399                           P36    78.0   others     itel        2
# 917                    150 (2020)    78.0   others    Nokia        2
# 664  Narzo 50 5G (4GB RAM + 64GB)    75.0  Android   Realme        2
# 690     Vision 3 (2GB RAM + 32GB)    78.0  Android     itel        2
# ..                            ...     ...      ...      ...      ...
# 667                        A96 4G    80.0  Android     OPPO        2
# 578                    Reno 8T 4G    83.0  Android     Oppo        2
# 355                          C30s    78.0  Android   Realme        2
# 574                           Y71    78.0  Android     Vivo        2
# 662                          V25e    84.0  Android     Vivo        2
#
#      network_type  NFC processor_brand  num_cores        clock_speed  ram_x  \
# ...

# %%
mobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1003 entries, 0 to 1019
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   model            1003 non-null   object
#  1   price            1003 non-null   float64
#  2   rating           1003 non-null   float64
#  3   os               1003 non-null   object
#  4   brand            1003 non-null   object
#  5   num_sim          1003 non-null   int64
#  6   network_type     1003 non-null   int64
#  7   NFC              1003 non-null   int64
#  8   processor_brand  1003 non-null   object
#  9   num_cores        1003 non-null   int64
#  10  clock_speed      1003 non-null   object
#  11  ram_x            1003 non-null   object
#  12  storage          1003 non-null   object
#  13  battery_cap      1003 non-null   object
#  14  charging         1003 non-null   object
#  15  camera_first     1003 non-null   object
# ...

# %%
ytrain
# Out:
# 175     9.648531
# 512     9.647950
# 912     9.740380
# 375    10.668932
# 200     9.798071
#          ...
# 536     9.158942
# 587     9.711055
# 494     9.089189
# 528     9.902987
# 168    10.341420
# Name: price, Length: 802, dtype: float64

# %%
ytest
# Out:
# 37     11.429533
# 399     8.778018
# 917     7.823646
# 664     9.510371
# 690     8.663024
#          ...
# 667     9.798071
# 578     9.903438
# 355     8.874168
# 574    10.126631
# 662     9.902987
# Name: price, Length: 201, dtype: float64

# %%
from sklearn.compose._column_transformer import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline

# %%
xtrain.head(1)
# Out:
#                          model  rating       os brand  num_sim  network_type  \
# 175  Z6 Lite (6GB RAM + 128GB)    79.0  Android  iQOO        2             5
#
#      NFC processor_brand  num_cores      clock_speed ram_x storage  \
# 175    0      Snapdragon          8  2 GHz Processor  6 GB  128 GB
#
#     battery_cap           charging camera_first camera_front
# 175        5000  18W Fast Charging           50            8

# %%
step1 = ColumnTransformer(transformers=[('col_trf',OneHotEncoder(sparse=False,drop = 'first',handle_unknown='ignore'),[0,2,3,7,9,10,11,13,14,15])
                                    ], remainder='passthrough')
step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(xtrain,ytrain)
ypred = pipe.predict(xtest)
print("R2 score : ", r2_score(ytest,ypred))
print("MAE : ", mean_absolute_error(ytest,ypred))
# Out:
# C:\Users\harsh\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score :  0.8544096927767777
# MAE :  0.21244763385320078
# C:\Users\harsh\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 2, 4, 5, 6, 7, 8, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[('col_trf',OneHotEncoder(sparse=False,drop = 'first',handle_unknown='ignore'),[0,2,3,7,9,10,11,13,14,15])
                                    ], remainder='passthrough')
step2 = RandomForestRegressor()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(xtrain,ytrain)
ypred = pipe.predict(xtest)
print("R2 score : ", r2_score(ytest,ypred))
print("MAE : ", mean_absolute_error(ytest,ypred))
# Out:
# C:\Users\harsh\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score :  0.8472535181534497
# MAE :  0.20217714682572807
# C:\Users\harsh\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 2, 4, 5, 6, 7, 8, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[('col_trf',OneHotEncoder(sparse=False,drop = 'first',handle_unknown='ignore'),[0,2,3,7,9,10,11,13,14,15])
                                    ], remainder='passthrough')
step2 = DecisionTreeRegressor()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(xtrain,ytrain)
ypred = pipe.predict(xtest)
print("R2 score : ", r2_score(ytest,ypred))
print("MAE : ", mean_absolute_error(ytest,ypred))
# Out:
# C:\Users\harsh\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\harsh\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 2, 4, 5, 6, 7, 8, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# R2 score :  0.7149248118412368
# MAE :  0.2634161507050281

# %%
step1 = ColumnTransformer(transformers=[('col_trf',OneHotEncoder(sparse=False,drop = 'first',handle_unknown='ignore'),[0,2,3,7,9,10,11,13,14,15])
                                    ], remainder='passthrough')
step2 = AdaBoostRegressor()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(xtrain,ytrain)
ypred = pipe.predict(xtest)
print("R2 score : ", r2_score(ytest,ypred))
print("MAE : ", mean_absolute_error(ytest,ypred))
# Out:
# C:\Users\harsh\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\harsh\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 2, 4, 5, 6, 7, 8, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# R2 score :  0.6979805182390474
# MAE :  0.33329243139794557

# %%
step1 = ColumnTransformer(transformers=[('col_trf',OneHotEncoder(sparse=False,drop = 'first',handle_unknown='ignore'),[0,2,3,7,9,10,11,13,14,15])
                                    ], remainder='passthrough')
step2 = RandomForestRegressor()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(xtrain,ytrain)
ypred = pipe.predict(xtest)
print("R2 score : ", r2_score(ytest,ypred))
print("MAE : ", mean_absolute_error(ytest,ypred))
# Out:
# C:\Users\harsh\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score :  0.8520688512194159
# MAE :  0.2007600120495018
# C:\Users\harsh\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 2, 4, 5, 6, 7, 8, 9] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
xtrain.head()
# Out:
#                          model  rating       os    brand  num_sim  \
# 175  Z6 Lite (6GB RAM + 128GB)    79.0  Android     iQOO        2
# 512              Galaxy F42 5G    80.0  Android  Samsung        2
# 912                  Nord N100    68.0  Android  OnePlus        2
# 375            Galaxy S10 Plus    81.0  Android  Samsung        2
# 200                       A77s    76.0  Android     OPPO        2
#
#      network_type  NFC processor_brand  num_cores        clock_speed ram_x  \
# 175             5    0      Snapdragon          8    2 GHz Processor  6 GB
# 512             5    0       Dimensity          8  2.2 GHz Processor  6 GB
# 912             4    0      Snapdragon          8  1.8 GHz Processor  4 GB
# 375             4    1          Exynos          8  2.7 GHz Processor  8 GB
# 200             4    0      Snapdragon          8  2.4 GHz Processor  8 GB
#
#     storage battery_cap           charging camera_first camera_front
# ...

# %%
# var= ('Galaxy',80.3,'Samsung',2,4,0,'Snapdragon',8,'2 GHz Processer','6 GB','128 GB',6000,'15W Fast Charging','48','20')

# %%
var = np.array(['Galaxy',80.3,'Android','Samsung',2,4,0,'Exynos',8,'2 GHz Processer','6 GB','128 GB',6000,'15W Fast Charging','48','20'])

# %%
var = var.reshape(1,16)

# %%
ans = pipe.predict(var)[0]
# Out:
# C:\Users\harsh\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# C:\Users\harsh\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
print(np.exp(ans))
# Out:
# 17831.456678031318

# %%
import pickle

# %%
pickle.dump(pipe,open("model.pkl","wb"))

# %%
mobile.head()
# Out:
#                model      price  rating       os     brand  num_sim  \
# 0              11 5G  10.915070    89.0  Android   OnePlus        2
# 1  Nord CE 2 Lite 5G   9.902937    81.0  Android   OnePlus        2
# 2      Galaxy A14 5G   9.711055    75.0  Android   Samsung        2
# 3        Moto G62 5G   9.615739    81.0  Android  Motorola        2
# 4        10 Pro Plus  10.126591    82.0  Android    Realme        2
#
#    network_type  NFC processor_brand  num_cores        clock_speed  ram_x  \
# 0             5    1      Snapdragon          8  3.2 GHz Processor  12 GB
# 1             5    0      Snapdragon          8  2.2 GHz Processor   6 GB
# 2             5    0          Exynos          8  2.4 GHz Processor   4 GB
# 3             5    0      Snapdragon          8  2.2 GHz Processor   6 GB
# 4             5    0       Dimensity          8  2.6 GHz Processor   6 GB
#
#   storage battery_cap            charging camera_first camera_front
# ...

# %%
pickle.dump(mobile.to_dict(),open("mobile.pkl","wb"))

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.2.1'

# %%
brand = 'OnePlus'

# %%
mobile[mobile['brand']==brand]['model'].unique()
# Out:
# array(['11 5G', 'Nord CE 2 Lite 5G', 'Nord 2T 5G', '10R 5G', '11R',
#        'Nord CE 2 Lite 5G (8GB RAM + 128GB)', '11 Pro', 'Nord CE 3 5G',
#        '10 Pro 5G', '10T', 'Ace Racing Edition 5G',
#        '10R 5G (12GB RAM + 256GB)', 'Nord 2T (12GB RAM + 256GB)',
#        'Nord CE 2 Lite 5G (8GB RAM + 256GB)', 'Clover', 'Nord 3 5G',
#        'Nord CE 3 Lite 5G', '10 Pro 5G (12GB RAM + 256GB)', 'Ace 2',
#        '10T (16GB RAM + 256GB)', '9RT 5G', '9 Pro', 'Nord N20 5G',
#        '10T (12GB RAM + 256GB)', 'Nord N200',
#        '10 Pro 5G (12GB RAM + 512GB)', '6 (8GB RAM + 128GB)', '12 Pro',
#        '10R Prime Edition', 'Nord 3T 5G', 'Nord Lite', 'Nord 2 Lite 5G',
#        'Nord 5', 'Nord N10', 'Nord N300', 'Nord 4 5G', 'Ace 5G', '9T',
#        'Nord SE', 'Nord N100', 'Ace Pro', 'Z'], dtype=object)

# %%
model = pickle.load(open("model.pkl","rb"))

# %%
model.predict(var)
# Out:
# C:\Users\harsh\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# C:\Users\harsh\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# array([9.78871941])
